# %%
import numpy as np
import pandas as pd

# %%
import os

loc = os.path.normpath(os.getcwd() + os.sep + os.pardir)
dataset_link = loc + '\dataset'

# %%
# Load order_payments_dataset
payment_df = pd.read_csv(dataset_link + r'\order_payments_dataset.csv')
payment_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1         cash
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1         cash
#
#         payment_installments  payment_value
# ...

# %%
# Overall

payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
payment_df['payment_type'].unique()
# Out:
# array(['credit_card', 'cash', 'voucher', 'debit_card', 'not_defined'],
#       dtype=object)

# %%
max(payment_df['payment_installments'])
# Out:
# 24

# %%
payment_df.groupby('order_id').order_id.count().sort_values(ascending=False)
# Out:
# order_id
# fa65dad1b0e818e3ccc5cb0e39231352    29
# ccf804e764ed5650cd8759557269dc13    26
# 285c2e15bebd4ac83635ccc563dc71f4    22
# 895ab968e7bb0d5659d16cd74cd1650c    21
# fedcd9f7ccdc8cba3a18defedd1a5547    19
#                                     ..
# 56bd45163229b35ca0ab490c1e3d3233     1
# 56bc98e6d5b88c2cdb905f2fbec2ca3a     1
# 56bbc7d92e6e74b8782abbf5ee336a92     1
# 56bafc014f8ed2f34cfe598592c65fd8     1
# fffe41c64501cc87c801fd61db3f6244     1
# Name: order_id, Length: 99440, dtype: int64

# %%
payment_df[payment_df['order_id'] == 'fa65dad1b0e818e3ccc5cb0e39231352']
# Out:
#                                 order_id  payment_sequential payment_type  \
# 4885    fa65dad1b0e818e3ccc5cb0e39231352                  27      voucher
# 9985    fa65dad1b0e818e3ccc5cb0e39231352                   4      voucher
# 14321   fa65dad1b0e818e3ccc5cb0e39231352                   1      voucher
# 17274   fa65dad1b0e818e3ccc5cb0e39231352                   9      voucher
# 19565   fa65dad1b0e818e3ccc5cb0e39231352                  10      voucher
# 23074   fa65dad1b0e818e3ccc5cb0e39231352                   2      voucher
# 24879   fa65dad1b0e818e3ccc5cb0e39231352                  25      voucher
# 28330   fa65dad1b0e818e3ccc5cb0e39231352                   5      voucher
# 29648   fa65dad1b0e818e3ccc5cb0e39231352                   6      voucher
# 32519   fa65dad1b0e818e3ccc5cb0e39231352                  11      voucher
# 36822   fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 39108   fa65dad1b0e818e3ccc5cb0e39231352                  29      voucher
# ...

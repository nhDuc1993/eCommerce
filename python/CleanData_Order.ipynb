# %%
import numpy as np
import pandas as pd

# %%
import os

loc = os.path.normpath(os.getcwd() + os.sep + os.pardir)
dataset_link = loc + '\dataset'

# %%
# Load orders_dataset
order_df = pd.read_csv(dataset_link + r'\orders_dataset.csv')
order_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# Overall

order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
# Check primary keys validity

print('Count of distinct values in \'order_id\' column:'  , len(pd.unique(order_df['order_id'])))
print('Count of distinct values in \'customer_id\' column:'  , len(pd.unique(order_df['customer_id'])))
# Out:
# Count of distinct values in 'order_id' column: 99441
# Count of distinct values in 'customer_id' column: 99441

# %%
# Check order_status
order_df['order_status'].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'unavailable',
#        'canceled', 'created', 'approved'], dtype=object)

# %%
# order_approved_at
order_df[pd.isnull(order_df['order_approved_at'])]['order_status'].unique()
# Out:
# array(['canceled', 'delivered', 'created'], dtype=object)

# %%
# order_delivered_carrier_date 
order_df[pd.isnull(order_df['order_delivered_carrier_date'])]['order_status'].unique()
# Out:
# array(['invoiced', 'processing', 'unavailable', 'canceled', 'created',
#        'approved', 'delivered'], dtype=object)

# %%
# order_delivered_customer_date
order_df[pd.isnull(order_df['order_delivered_customer_date'])]['order_status'].unique()
# Out:
# array(['invoiced', 'shipped', 'processing', 'unavailable', 'canceled',
#        'delivered', 'created', 'approved'], dtype=object)

# %%
delivered_customer_df = order_df[['delivered_carrier', 'order_delivered_customer_date']].dropna()
delivered_customer_average = round(delivered_customer_df.apply(lambda x: time_diff(x['delivered_carrier'], x['order_delivered_customer_date']).seconds, axis=1).mean())
order_df['delivered_customer'] = order_df.apply(lambda x: time_add(x['delivered_carrier'], delivered_customer_average) 
                                                if x['order_delivered_customer_date'] != x['order_delivered_customer_date'] 
                                                else x['order_delivered_customer_date'], axis=1 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-8ce489c5d859> in <module>
# ----> 1 delivered_customer_df = order_df[['delivered_carrier', 'order_delivered_customer_date']].dropna()
#       2 delivered_customer_average = round(delivered_customer_df.apply(lambda x: time_diff(x['delivered_carrier'], x['order_delivered_customer_date']).seconds, axis=1).mean())
#       3 order_df['delivered_customer'] = order_df.apply(lambda x: time_add(x['delivered_carrier'], delivered_customer_average)
#       4                                                 if x['order_delivered_customer_date'] != x['order_delivered_customer_date']
#       5                                                 else x['order_delivered_customer_date'], axis=1 )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
# ...
